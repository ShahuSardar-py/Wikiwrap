# %%
print("Ganpati bappa morya")
# Out:
# Ganpati bappa morya

# %%
import langchain_groq

# %%
from langchain_groq import ChatGroq

# %%
import os
os.environ['GROQ_API_KEY']= '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'

# %%
llm=ChatGroq(
    temperature=1,
    model_name="llama-3.1-70b-versatile"
)

# %%
def get_response(url):
    response = llm.invoke(input)
    print(response)

# %%
from langchain_community.document_loaders import WebBaseLoader
link=input("your link")

loader=WebBaseLoader(link)
pg_data= loader.load().pop().page_content
# Out:
# API - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
# Donate Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Purpose
#
#
#
#
#
#
#
#
# 2
# History of the term
#
#
#
#
#
#
#
#
# 3
# Types
#
#
#
#
# Toggle Types subsection
#
#
#
#
#
# 3.1
# Libraries and frameworks
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate




prompt_template = PromptTemplate.from_template(
        """
    You are  a smart content summarizer. You help students to get relaible information sourced from Wikipedia about the topic {pg_data} and summarize it in best and simple format. It should be 100 words only. NO PREAMBLE
        """
        )
chain_response = prompt_template | llm
res= chain_response.invoke({"pg_data": pg_data})
print(res.content)
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[15], line 12
#       6 prompt_template = PromptTemplate.from_template(
#       7         """
#       8     You are  a smart content summarizer. You help students to get relaible information sourced from Wikipedia about the topic {pg_data} and summarize it in best and simple format. It should be 100 words only. NO PREAMBLE
#       9         """
#      10         )
#      11 chain_response = prompt_template | llm
# ---> 12 res= chain_response.invoke({"pg_data": pg_data})
#      13 print(res.content)
#
# File c:\Users\User\.conda\envs\cenv\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

link = input("Enter your link: ")

loader = WebBaseLoader(link)
docs = loader.load()

# Extract the page content
page_content = docs[0].page_content

# Extract the first 1000 words
first_3000_words = page_content[:3000]

print(first_3000_words)
# Out:
# API - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
# Donate Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Purpose
#
#
#
#
#
#
#
#
# 2
# History of the term
#
#
#
#
#
#
#
#
# 3
# Types
#
#
#
#
# Toggle Types subsection
#
#
#
#
#
# 3.1
# Libraries and frameworks
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate




prompt_template = PromptTemplate.from_template(
        """
    You are  a smart content summarizer. You help students to get relaible information sourced from Wikipedia about the topic {pg_data} and summarize it in best and simple format. It should be 100 words only. NO PREAMBLE
        """
        )
chain_response = prompt_template | llm
res= chain_response.invoke({"pg_data": first_3000_words})
print(res.content)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 12
#       6 prompt_template = PromptTemplate.from_template(
#       7         """
#       8     You are  a smart content summarizer. You help students to get relaible information sourced from Wikipedia about the topic {first_3000_words} and summarize it in best and simple format. It should be 100 words only. NO PREAMBLE
#       9         """
#      10         )
#      11 chain_response = prompt_template | llm
# ---> 12 res= chain_response.invoke({"pg_data": first_3000_words})
#      13 print(res.content)
#
# File c:\Users\User\.conda\envs\cenv\Lib\site-packages\langchain_core\runnables\base.py:3022, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3020 context.run(_set_config_context, config)
#    3021 if i == 0:
# -> 3022     input = context.run(step.invoke, input, config, **kwargs)
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader
link=input("your link")

loader=WebBaseLoader(link)
pg_data= loader.load().pop().page_content

# %%
first_3000_words = pg_data[:3000]

print(first_3000_words)
# Out:
# API - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
# Donate Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Purpose
#
#
#
#
#
#
#
#
# 2
# History of the term
#
#
#
#
#
#
#
#
# 3
# Types
#
#
#
#
# Toggle Types subsection
#
#
#
#
#
# 3.1
# Libraries and frameworks
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template("Topic ontent: {first_3000_words}. The provided content is sourced from Wikipedia. Summarize and explain about it in simple terms. NO PREAMBLE ")

prompt_template.invoke({"first_3000_words": "first_3000_words"})



chain_response =  prompt_template| llm
res = chain_response.invoke({"first_3000_words": first_3000_words})
print(res.content)
# Out:
# An Application Programming Interface (API) is a connection that allows computers or programs to communicate with each other. It's a set of rules that defines how a computer or program can request services from another.
#
# Think of an API like a messenger between different systems. You ask the messenger (API) for something, and if the request is in the correct format (according to the API specifications), the messenger will collect what you need from the other system and bring it back to you.
#
# For example, imagine you're using a travel app to book a hotel. When you enter your destination and dates, the app sends a request to a hotel booking API. The API checks the request and then searches the hotel database for available rooms. It then sends the list of available hotels back to the travel app, which displays the options to you.
#
# APIs can be used for various purposes, including:
#
# 1. Libraries and frameworks: A set of tools for building software applications.
# ...
